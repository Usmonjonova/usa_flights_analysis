# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

flights = pd.read_csv('flights.csv')
airports = pd.read_csv('airports.csv')
airlines = pd.read_csv('airlines.csv')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_16856\813594282.py:7: DtypeWarning: Columns (0: ORIGIN_AIRPORT, 1: DESTINATION_AIRPORT) have mixed types. Specify dtype option on import or set low_memory=False.
#   flights = pd.read_csv('flights.csv')

# %%
flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
# 3     258.0      2342      748.0      8.0                805         756.0
# 4     199.0      1448      254.0      5.0                320         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='str')

# %%
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
flights.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   YEAR                 int64
#  1   MONTH                int64
#  2   DAY                  int64
#  3   DAY_OF_WEEK          int64
#  4   AIRLINE              str
#  5   FLIGHT_NUMBER        int64
#  6   TAIL_NUMBER          str
#  7   ORIGIN_AIRPORT       object
#  8   DESTINATION_AIRPORT  object
#  9   SCHEDULED_DEPARTURE  int64
#  10  DEPARTURE_TIME       float64
#  11  DEPARTURE_DELAY      float64
#  12  TAXI_OUT             float64
#  13  WHEELS_OFF           float64
#  14  SCHEDULED_TIME       float64
#  15  ELAPSED_TIME         float64
#  16  AIR_TIME             float64
#  17  DISTANCE             int64
#  18  WHEELS_ON            float64
#  19  TAXI_IN              float64
#  20  SCHEDULED_ARRIVAL    int64
#  21  ARRIVAL_TIME         float64
#  22  ARRIVAL_DELAY        float64
#  23  DIVERTED             int64
#  24  CANCELLED            int64
#  25  CANCELLATION_REASON  str
#  26  AIR_SYSTEM_DELAY     float64
#  27  SECURITY_DELAY       float64
#  28  AIRLINE_DELAY        float64
#  29  LATE_AIRCRAFT_DELAY  float64
#  30  WEATHER_DELAY        float64
# dtypes: float64(16), int64(10), object(2), str(3)
# memory usage: 1.3+ GB

# %%
airlines.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  14 non-null     str
#  1   AIRLINE    14 non-null     str
# dtypes: str(2)
# memory usage: 356.0 bytes

# %%
airports.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   IATA_CODE  322 non-null    str
#  1   AIRPORT    322 non-null    str
#  2   CITY       322 non-null    str
#  3   STATE      322 non-null    str
#  4   COUNTRY    322 non-null    str
#  5   LATITUDE   319 non-null    float64
#  6   LONGITUDE  319 non-null    float64
# dtypes: float64(2), str(5)
# memory usage: 17.7 KB

# %%
### Airlines qo'shish
# flights = flights.merge(airlines, how='left', left_on='AIRLINE', right_on='IATA_CODE')


### Origin airport ma'lumotlarini qo'shish
# airports_origin = airports.add_prefix('ORIGIN_')
# flights = flights.merge(airports_origin, how='left', left_on='ORIGIN_AIRPORT', right_on='ORIGIN_IATA_CODE')
# flights.drop(columns=['ORIGIN_AIRPORT_x'], inplace=True)

### Destination airport ma'lumotlarini qo'shish
# airports_dest = airports.add_prefix('DEST_')
# flights = flights.merge(airports_dest, how='left', left_on='DESTINATION_AIRPORT', right_on='DEST_IATA_CODE')


# flights.drop(columns=['DEST_LONGITUDE'], inplace=True)
# flights = flights.rename(columns={'AIRLINE': 'AIRLINE_x'})
# flights.columns.tolist()

# flights.columns.values[-6] = 'AIRLINE'

# flights.columns.tolist()

flights.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4        AS             98      N407AS
# 1  2015      1    1            4        AA           2336      N3KUAA
# 2  2015      1    1            4        US            840      N171US
# 3  2015      1    1            4        AA            258      N3HYAA
# 4  2015      1    1            4        AS            135      N527AS
#
#   DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  \
# 0                 SEA                    5          2354.0            -11.0
# 1                 PBI                   10             2.0             -8.0
# 2                 CLT                   20            18.0             -2.0
# 3                 MIA                   20            15.0             -5.0
# 4                 ANC                   25            24.0             -1.0
#
#    TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 0      21.0        15.0           205.0         194.0     169.0      1448
# 1      12.0        14.0           280.0         279.0     263.0      2330
# 2      16.0        34.0           286.0         293.0     266.0      2296
# 3      15.0        30.0           285.0         281.0     258.0      2342
# 4      11.0        35.0           235.0         215.0     199.0      1448
#
#    WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# 0      404.0      4.0                430         408.0          -22.0
# 1      737.0      4.0                750         741.0           -9.0
# 2      800.0     11.0                806         811.0            5.0
# 3      748.0      8.0                805         756.0           -9.0
# 4      254.0      5.0                320         259.0          -21.0
#
#    DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 0         0          0                 NaN               NaN             NaN
# 1         0          0                 NaN               NaN             NaN
# 2         0          0                 NaN               NaN             NaN
# 3         0          0                 NaN               NaN             NaN
# 4         0          0                 NaN               NaN             NaN
#
#    AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY               AIRLINE_y  \
# 0            NaN                  NaN            NaN    Alaska Airlines Inc.
# 1            NaN                  NaN            NaN  American Airlines Inc.
# 2            NaN                  NaN            NaN         US Airways Inc.
# 3            NaN                  NaN            NaN  American Airlines Inc.
# 4            NaN                  NaN            NaN    Alaska Airlines Inc.
#
#                               ORIGIN_AIRPORT_y    ORIGIN_CITY ORIGIN_STATE  \
# 0  Ted Stevens Anchorage International Airport      Anchorage           AK
# 1            Los Angeles International Airport    Los Angeles           CA
# 2          San Francisco International Airport  San Francisco           CA
# 3            Los Angeles International Airport    Los Angeles           CA
# 4         Seattle-Tacoma International Airport        Seattle           WA
#
#                                   DEST_AIRPORT        DEST_CITY DEST_STATE
# 0         Seattle-Tacoma International Airport          Seattle         WA
# 1             Palm Beach International Airport  West Palm Beach         FL
# 2      Charlotte Douglas International Airport        Charlotte         NC
# 3                  Miami International Airport            Miami         FL
# 4  Ted Stevens Anchorage International Airport        Anchorage         AK

# %%
def analyze_columns(df, missing_threshold=0.9, unique_threshold=1):
    
    # o'chirish uchun keraksiz columnlarni aniqlanadi
    
    report = []
    
    for col in df.columns:
        missing_pct = df[col].isnull().sum() / len(df)
        unique_count = df[col].nunique()
        unique_pct = unique_count / len(df)
        
        if missing_pct > missing_threshold:
            status = f"High missing ({missing_pct:.1%})"
        elif unique_count <= unique_threshold:
            status = "Zero variance"
        elif unique_pct > 0.99:
            status = "Likely ID column"
        else:
            status = "Keep"
        
        report.append({
            'Column': col,
            'Type': str(df[col].dtype),
            'Missing%': f"{missing_pct:.2%}",
            'Unique': unique_count,
            'Status': status
        })
    
    return pd.DataFrame(report)

column_report = analyze_columns(flights)
print(column_report.to_string())

cols_to_drop = column_report[column_report['Status'] != 'Keep']['Column'].tolist()
print(f"\nColumns to drop: {cols_to_drop}")
# Out:
#                  Column     Type Missing%  Unique                Status
# 0                  YEAR    int64    0.00%       1         Zero variance
# 1                 MONTH    int64    0.00%      12                  Keep
# 2                   DAY    int64    0.00%      31                  Keep
# 3           DAY_OF_WEEK    int64    0.00%       7                  Keep
# 4             AIRLINE_x      str    0.00%      14                  Keep
# 5         FLIGHT_NUMBER    int64    0.00%    6952                  Keep
# 6           TAIL_NUMBER      str    0.25%    4897                  Keep
# 7   DESTINATION_AIRPORT   object    0.00%     930                  Keep
# 8   SCHEDULED_DEPARTURE    int64    0.00%    1321                  Keep
# 9        DEPARTURE_TIME  float64    1.48%    1440                  Keep
# 10      DEPARTURE_DELAY  float64    1.48%    1217                  Keep
# 11             TAXI_OUT  float64    1.53%     184                  Keep
# 12           WHEELS_OFF  float64    1.53%    1440                  Keep
# 13       SCHEDULED_TIME  float64    0.00%     550                  Keep
# 14         ELAPSED_TIME  float64    1.81%     712                  Keep
# 15             AIR_TIME  float64    1.81%     675                  Keep
# 16             DISTANCE    int64    0.00%    1363                  Keep
# 17            WHEELS_ON  float64    1.59%    1440                  Keep
# 18              TAXI_IN  float64    1.59%     185                  Keep
# 19    SCHEDULED_ARRIVAL    int64    0.00%    1435                  Keep
# 20         ARRIVAL_TIME  float64    1.59%    1440                  Keep
# 21        ARRIVAL_DELAY  float64    1.81%    1240                  Keep
# 22             DIVERTED    int64    0.00%       2                  Keep
# 23            CANCELLED    int64    0.00%       2                  Keep
# 24  CANCELLATION_REASON      str   98.46%       4  High missing (98.5%)
# 25     AIR_SYSTEM_DELAY  float64   81.72%     570                  Keep
# 26       SECURITY_DELAY  float64   81.72%     154                  Keep
# 27        AIRLINE_DELAY  float64   81.72%    1067                  Keep
# 28  LATE_AIRCRAFT_DELAY  float64   81.72%     695                  Keep
# 29        WEATHER_DELAY  float64   81.72%     632                  Keep
# 30            AIRLINE_y      str    0.00%      14                  Keep
# 31     ORIGIN_AIRPORT_y   object    8.35%     322                  Keep
# 32          ORIGIN_CITY      str    8.35%     308                  Keep
# 33         ORIGIN_STATE      str    8.35%      54                  Keep
# 34         DEST_AIRPORT      str    8.35%     322                  Keep
# 35            DEST_CITY      str    8.35%     308                  Keep
# 36           DEST_STATE      str    8.35%      54                  Keep
#
# Columns to drop: ['YEAR', 'CANCELLATION_REASON']

# %%
# datasetdagi hamma year valuelari bir hil bo'lgani uchun uni o'chirib yuborish

flights['YEAR'].nunique()

flights = flights.drop(columns=['YEAR'])

# %%
#  data turi son bolgan columnlardagi bo'sh cellarni 0 bilan to'ldirish

delay_columns = [
    'DEPARTURE_DELAY',
    'ARRIVAL_DELAY',
    'AIR_SYSTEM_DELAY',
    'SECURITY_DELAY',
    'AIRLINE_DELAY',
    'LATE_AIRCRAFT_DELAY',
    'WEATHER_DELAY'
]

for col in delay_columns:
    if col in flights.columns:
        flights[col] = flights[col].fillna(0)

# %%
# CANCELLATION_REASON NaN bo'lganda uni Not Cancelled bilan almashtirish

flights['CANCELLATION_REASON'] = flights['CANCELLATION_REASON'].fillna('Not Cancelled')

# %%
# TAIL_NUMBER da 14721 ta NaN borligi uchun shu rowlar o'chirib tashlandi

flights = flights.dropna(subset=['TAIL_NUMBER'])

# %%
# Data Typelarni to'g'irlash

flights.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5804358 entries, 0 to 5819078
# Data columns (total 36 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   MONTH                int64
#  1   DAY                  int64
#  2   DAY_OF_WEEK          int64
#  3   AIRLINE_x            str
#  4   FLIGHT_NUMBER        int64
#  5   TAIL_NUMBER          str
#  6   DESTINATION_AIRPORT  object
#  7   SCHEDULED_DEPARTURE  int64
#  8   DEPARTURE_TIME       float64
#  9   DEPARTURE_DELAY      float64
#  10  TAXI_OUT             float64
#  11  WHEELS_OFF           float64
#  12  SCHEDULED_TIME       float64
#  13  ELAPSED_TIME         float64
#  14  AIR_TIME             float64
#  15  DISTANCE             int64
#  16  WHEELS_ON            float64
#  17  TAXI_IN              float64
#  18  SCHEDULED_ARRIVAL    int64
#  19  ARRIVAL_TIME         float64
#  20  ARRIVAL_DELAY        float64
#  21  DIVERTED             int64
#  22  CANCELLED            int64
#  23  CANCELLATION_REASON  str
#  24  AIR_SYSTEM_DELAY     float64
#  25  SECURITY_DELAY       float64
#  26  AIRLINE_DELAY        float64
#  27  LATE_AIRCRAFT_DELAY  float64
#  28  WEATHER_DELAY        float64
#  29  AIRLINE_y            str
#  30  ORIGIN_AIRPORT_y     object
#  31  ORIGIN_CITY          str
#  32  ORIGIN_STATE         str
#  33  DEST_AIRPORT         str
#  34  DEST_CITY            str
#  35  DEST_STATE           str
# dtypes: float64(16), int64(9), object(2), str(9)
# memory usage: 1.6+ GB

# %%
# # data typeni int ga o'zgaritish

# int_columns = ['MONTH', 'DAY', 'DAY_OF_WEEK', 'FLIGHT_NUMBER', 'DISTANCE',
#                'DIVERTED', 'CANCELLED']

# for col in int_columns:
#     if col in flights.columns:
#         # Agar NaN bo‘lishi mumkin bo‘lsa, nullable integer Int32 ishlatamiz
#         flights[col] = flights[col].astype('Int32')

# %%
flights.isnull().sum()
# Out:
# MONTH                       0
# DAY                         0
# DAY_OF_WEEK                 0
# AIRLINE_x                   0
# FLIGHT_NUMBER               0
# TAIL_NUMBER                 0
# DESTINATION_AIRPORT         0
# SCHEDULED_DEPARTURE         0
# DEPARTURE_TIME          71432
# DEPARTURE_DELAY             0
# TAXI_OUT                74326
# WHEELS_OFF              74326
# SCHEDULED_TIME              6
# ELAPSED_TIME            90350
# AIR_TIME                90350
# DISTANCE                    0
# WHEELS_ON               77792
# TAXI_IN                 77792
# SCHEDULED_ARRIVAL           0
# ARRIVAL_TIME            77792
# ARRIVAL_DELAY               0
# DIVERTED                    0
# CANCELLED                   0
# CANCELLATION_REASON         0
# AIR_SYSTEM_DELAY            0
# SECURITY_DELAY              0
# AIRLINE_DELAY               0
# LATE_AIRCRAFT_DELAY         0
# WEATHER_DELAY               0
# AIRLINE_y                   0
# ORIGIN_AIRPORT_y       485811
# ORIGIN_CITY            485811
# ORIGIN_STATE           485811
# DEST_AIRPORT           485811
# DEST_CITY              485811
# DEST_STATE             485811
# dtype: int64

# %%
# 4.Har bir aviakompaniya bo‘yicha o‘rtacha kechikishni hisoblang. 

flights.groupby('AIRLINE_y')['DEPARTURE_DELAY'].mean()
# Out:
# AIRLINE_y
# Alaska Airlines Inc.             1.779476
# American Airlines Inc.           8.801537
# American Eagle Airlines Inc.     9.633612
# Atlantic Southeast Airlines      8.493231
# Delta Air Lines Inc.             7.338308
# Frontier Airlines Inc.          13.350858
# Hawaiian Airlines Inc.           0.485713
# JetBlue Airways                 11.333045
# Skywest Airlines Inc.            7.679601
# Southwest Airlines Co.          10.461756
# Spirit Air Lines                15.683274
# US Airways Inc.                  6.141137
# United Air Lines Inc.           14.434818
# Virgin America                   8.947095
# Name: DEPARTURE_DELAY, dtype: float64

# %%
# 5.Eng kam kechikish bilan ishlovchi 5 ta aviakompaniyani aniqlang

flights.groupby('AIRLINE_y')['DEPARTURE_DELAY'].min().sort_values().head(5)
# Out:
# AIRLINE_y
# Alaska Airlines Inc.          -82.0
# American Airlines Inc.        -68.0
# Delta Air Lines Inc.          -61.0
# Skywest Airlines Inc.         -56.0
# Atlantic Southeast Airlines   -55.0
# Name: DEPARTURE_DELAY, dtype: float64

# %%
# 6.Eng ko‘p parvoz amalga oshirilgan aviakompaniyani aniqlang. 

flights.groupby('AIRLINE_y')['FLIGHT_NUMBER'].count().sort_values(ascending=False).head(1)
# Out:
# AIRLINE_y
# Southwest Airlines Co.    1260450
# Name: FLIGHT_NUMBER, dtype: int64

# %%
# 7.Eng ko‘p ishlatiladigan jo‘nash shahrini aniqlang

flights.groupby('DEST_CITY')['FLIGHT_NUMBER'].count().sort_values(ascending=False).head(1)
# Out:
# DEST_CITY
# Chicago    365315
# Name: FLIGHT_NUMBER, dtype: int64

# %%
# 8.Eng ko‘p ishlatiladigan yo‘nalishni (shahar → shahar) aniqlang. 

flights.groupby(['ORIGIN_CITY', 'DEST_CITY'])['FLIGHT_NUMBER'].count().sort_values(ascending=False).head(1)
# Out:
# ORIGIN_CITY    DEST_CITY
# San Francisco  Los Angeles    13714
# Name: FLIGHT_NUMBER, dtype: int64

# %%
# 9.Har bir oy bo‘yicha o‘rtacha kechikishni hisoblang. 
import calendar

flights['MONTH_NAME'] = flights['MONTH'].apply(lambda x: calendar.month_name[x])

# flights.groupby('MONTH_NAME')['ARRIVAL_DELAY'].mean()
flights.groupby('MONTH_NAME')['DEPARTURE_DELAY'].mean()
# Out:
# MONTH_NAME
# April         7.663338
# August        9.855858
# December     11.622872
# February     11.425480
# January       9.574073
# July         11.311745
# June         13.784948
# March         9.491236
# May           9.363566
# November      6.887641
# October       4.962302
# September     4.806845
# Name: DEPARTURE_DELAY, dtype: float64

# %%
# 10.Har bir aviakompaniya uchun maksimal kechikishni aniqlang. 

flights.groupby('AIRLINE_y')['DEPARTURE_DELAY'].max().sort_values(ascending=False)
# Out:
# AIRLINE_y
# American Airlines Inc.          1988.0
# American Eagle Airlines Inc.    1544.0
# Hawaiian Airlines Inc.          1433.0
# Skywest Airlines Inc.           1378.0
# United Air Lines Inc.           1314.0
# Delta Air Lines Inc.            1289.0
# Atlantic Southeast Airlines     1274.0
# Frontier Airlines Inc.          1112.0
# JetBlue Airways                 1006.0
# Alaska Airlines Inc.             963.0
# Spirit Air Lines                 836.0
# US Airways Inc.                  759.0
# Southwest Airlines Co.           665.0
# Virgin America                   644.0
# Name: DEPARTURE_DELAY, dtype: float64

# %%
# 11. Eng katta kechikish kuzatilgan 10 ta yozuvni aniqlang. 

# flights['DEPARTURE_DELAY'].sort_values(ascending=False).head(10)

delays = flights.sort_values(by='DEPARTURE_DELAY', ascending=False).head(10)

print(delays)
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 337720       1   23            5        AA           1322      N598AA
# 3412085      8    1            6        AA             96      N479AA
# 4103531      9   13            7        AA           1063      N3CAAA
# 5810811     12   31            4        AA           2214      N4XKAA
# 5279939     11   27            5        AA           2559      N489AA
# 3100911      7   13            1        AA           1319      N3LEAA
# 1278418      3   24            2        AA           1279      N559AA
# 264495       1   18            7        AA            224      N5DGAA
# 949876       3    4            3        AA            270      N5DJAA
# 886984       2   28            6        AA           1312      N028AA
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 337720                  DFW                  700          1608.0
# 3412085                 DFW                  709          1427.0
# 4103531                 DFW                  700          1050.0
# 5810811                 DFW                 1041          1410.0
# 5279939                 ORD                 1027          1338.0
# 3100911                 LAX                 1905          2210.0
# 1278418                 DFW                 1103          1352.0
# 264495                  LAX                 1130          1414.0
# 949876                  LAX                  828          1057.0
# 886984                  MIA                  620           847.0
#
#          DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 337720            1988.0      13.0      1621.0           134.0         117.0
# 3412085           1878.0      28.0      1455.0           185.0         205.0
# 4103531           1670.0      26.0      1116.0           179.0         174.0
# 5810811           1649.0      12.0      1422.0           104.0          91.0
# 5279939           1631.0      14.0      1352.0            82.0          89.0
# 3100911           1625.0      34.0      2244.0           268.0         279.0
# 1278418           1609.0       6.0      1358.0           112.0         101.0
# 264495            1604.0      16.0      1430.0            76.0          65.0
# 949876            1589.0      23.0      1120.0           327.0         314.0
# 886984            1587.0      71.0       958.0           168.0         208.0
#
#          AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  \
# 337720       99.0       597     1800.0      5.0                914
# 3412085     156.0      1158     1631.0     21.0                914
# 4103531     142.0      1171     1538.0      6.0               1159
# 5810811      69.0       569     1631.0     10.0               1325
# 5279939      56.0       235     1348.0     19.0               1049
# 3100911     238.0      1814     2342.0      7.0               2033
# 1278418      90.0       583     1528.0      5.0               1255
# 264495       42.0       236     1512.0      7.0               1246
# 949876      282.0      2556     1802.0      9.0               1555
# 886984      131.0      1068     1309.0      6.0               1008
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 337720         1805.0         1971.0         0          0       Not Cancelled
# 3412085        1652.0         1898.0         0          0       Not Cancelled
# 4103531        1544.0         1665.0         0          0       Not Cancelled
# 5810811        1641.0         1636.0         0          0       Not Cancelled
# 5279939        1407.0         1638.0         0          0       Not Cancelled
# 3100911        2349.0         1636.0         0          0       Not Cancelled
# 1278418        1533.0         1598.0         0          0       Not Cancelled
# 264495         1519.0         1593.0         0          0       Not Cancelled
# 949876         1811.0         1576.0         0          0       Not Cancelled
# 886984         1315.0         1627.0         0          0       Not Cancelled
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 337720                0.0             0.0         1971.0                  0.0
# 3412085              20.0             0.0         1878.0                  0.0
# 4103531               0.0             0.0         1665.0                  0.0
# 5810811               0.0             0.0         1636.0                  0.0
# 5279939               7.0             0.0         1631.0                  0.0
# 3100911              11.0             0.0         1625.0                  0.0
# 1278418               0.0             0.0         1563.0                 35.0
# 264495                0.0             0.0         1593.0                  0.0
# 949876                0.0             0.0         1576.0                  0.0
# 886984               40.0             0.0         1587.0                  0.0
#
#          WEATHER_DELAY               AIRLINE_y  \
# 337720             0.0  American Airlines Inc.
# 3412085            0.0  American Airlines Inc.
# 4103531            0.0  American Airlines Inc.
# 5810811            0.0  American Airlines Inc.
# 5279939            0.0  American Airlines Inc.
# 3100911            0.0  American Airlines Inc.
# 1278418            0.0  American Airlines Inc.
# 264495             0.0  American Airlines Inc.
# 949876             0.0  American Airlines Inc.
# 886984             0.0  American Airlines Inc.
#
#                                           ORIGIN_AIRPORT_y   ORIGIN_CITY  \
# 337720      Birmingham-Shuttlesworth International Airport    Birmingham
# 3412085                     Richmond International Airport      Richmond
# 4103531  San Diego International Airport (Lindbergh Field)     San Diego
# 5810811                  Albuquerque International Sunport   Albuquerque
# 5279939                       Detroit Metropolitan Airport       Detroit
# 3100911                 Indianapolis International Airport  Indianapolis
# 1278418                                    Eppley Airfield         Omaha
# 264495                      McCarran International Airport     Las Vegas
# 949876                      Honolulu International Airport      Honolulu
# 886984    St. Louis International Airport at Lambert Field      St Louis
#
#         ORIGIN_STATE                             DEST_AIRPORT  \
# 337720            AL  Dallas/Fort Worth International Airport
# 3412085           VA  Dallas/Fort Worth International Airport
# 4103531           CA  Dallas/Fort Worth International Airport
# 5810811           NM  Dallas/Fort Worth International Airport
# 5279939           MI     Chicago O'Hare International Airport
# 3100911           IN        Los Angeles International Airport
# 1278418           NE  Dallas/Fort Worth International Airport
# 264495            NV        Los Angeles International Airport
# 949876            HI        Los Angeles International Airport
# 886984            MO              Miami International Airport
#
#                  DEST_CITY DEST_STATE MONTH_NAME
# 337720   Dallas-Fort Worth         TX    January
# 3412085  Dallas-Fort Worth         TX     August
# 4103531  Dallas-Fort Worth         TX  September
# 5810811  Dallas-Fort Worth         TX   December
# 5279939            Chicago         IL   November
# 3100911        Los Angeles         CA       July
# 1278418  Dallas-Fort Worth         TX      March
# 264495         Los Angeles         CA    January
# 949876         Los Angeles         CA      March
# 886984               Miami         FL   February

# %%
# 12.Masofa bo‘yicha eng uzoq 5 ta parvozni aniqlang.

longest_flight = flights.sort_values(by='DISTANCE', ascending=False).head(5)

print(longest_flight)
# Out:
#          MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 5623060     12   19            6        DL            426      N191DN
# 5721553     12   25            5        HA             50      N382HA
# 3227509      7   21            2        HA             51      N385HA
# 1087287      3   12            4        HA             50      N375HA
# 2494771      6    7            7        HA             50      N391HA
#
#         DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 5623060                 HNL                  845           854.0
# 5721553                 JFK                 1620          1617.0
# 3227509                 HNL                 1000           957.0
# 1087287                 JFK                 1535          1528.0
# 2494771                 JFK                 1520          1527.0
#
#          DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 5623060              9.0      40.0       934.0           705.0         675.0
# 5721553             -3.0      21.0      1638.0           575.0         564.0
# 3227509             -3.0      17.0      1014.0           640.0         660.0
# 1087287             -7.0      14.0      1542.0           560.0         545.0
# 2494771              7.0      13.0      1540.0           575.0         583.0
#
#          AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  \
# 5623060     631.0      4983     1505.0      4.0               1530
# 5721553     533.0      4983      631.0     10.0                655
# 3227509     639.0      4983     1453.0      4.0               1440
# 1087287     519.0      4983      621.0     12.0                655
# 2494771     560.0      4983      700.0     10.0                655
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 5623060        1509.0          -21.0         0          0       Not Cancelled
# 5721553         641.0          -14.0         0          0       Not Cancelled
# 3227509        1457.0           17.0         0          0       Not Cancelled
# 1087287         633.0          -22.0         0          0       Not Cancelled
# 2494771         710.0           15.0         0          0       Not Cancelled
#
#          AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 5623060               0.0             0.0            0.0                  0.0
# 5721553               0.0             0.0            0.0                  0.0
# 3227509               0.0             0.0           17.0                  0.0
# 1087287               0.0             0.0            0.0                  0.0
# 2494771               0.0             0.0           15.0                  0.0
#
#          WEATHER_DELAY               AIRLINE_y  \
# 5623060            0.0    Delta Air Lines Inc.
# 5721553            0.0  Hawaiian Airlines Inc.
# 3227509            0.0  Hawaiian Airlines Inc.
# 1087287            0.0  Hawaiian Airlines Inc.
# 2494771            0.0  Hawaiian Airlines Inc.
#
#                                           ORIGIN_AIRPORT_y ORIGIN_CITY  \
# 5623060  John F. Kennedy International Airport (New Yor...    New York
# 5721553                     Honolulu International Airport    Honolulu
# 3227509  John F. Kennedy International Airport (New Yor...    New York
# 1087287                     Honolulu International Airport    Honolulu
# 2494771                     Honolulu International Airport    Honolulu
#
#         ORIGIN_STATE                                       DEST_AIRPORT  \
# 5623060           NY                     Honolulu International Airport
# 5721553           HI  John F. Kennedy International Airport (New Yor...
# 3227509           NY                     Honolulu International Airport
# 1087287           HI  John F. Kennedy International Airport (New Yor...
# 2494771           HI  John F. Kennedy International Airport (New Yor...
#
#         DEST_CITY DEST_STATE MONTH_NAME
# 5623060  Honolulu         HI   December
# 5721553  New York         NY   December
# 3227509  Honolulu         HI       July
# 1087287  New York         NY      March
# 2494771  New York         NY       June

# %%
# 13.Har bir jo‘nash shahri bo‘yicha o‘rtacha kechikishni hisoblang. 

flights.groupby('DEST_CITY')['DEPARTURE_DELAY'].mean().sort_values(ascending=False)
# Out:
# DEST_CITY
# Agana         22.765060
# Marquette     19.491803
# St Cloud      18.280488
# Trenton       17.690837
# Aguadilla     17.323376
#                 ...
# Pocatello     -2.140673
# Lewiston      -2.253833
# Moab          -2.956311
# Dillingham    -5.532468
# Vernal        -5.736585
# Name: DEPARTURE_DELAY, Length: 308, dtype: float64

# %%
# 14.Har bir yo‘nalish bo‘yicha o‘rtacha kechikishni hisoblang. 

flights.groupby(['ORIGIN_CITY', 'DEST_CITY'])['DEPARTURE_DELAY'].mean().sort_values(ascending=False)
# Out:
# ORIGIN_CITY     DEST_CITY
# Chantilly       Trenton                341.000000
# Newburgh        West Palm Beach        256.000000
# Raleigh         Indianapolis           209.000000
# Corpus Christi  Harlingen              206.000000
# Springfield     Hays                   206.000000
#                                           ...
# Augusta         New York               -11.000000
# Long Beach      Phoenix                -12.000000
# Boise           Eugene                 -13.000000
# Rock Springs    Gillette               -16.074074
# Brainerd        International Falls    -26.000000
# Name: DEPARTURE_DELAY, Length: 4335, dtype: float64

# %%
# 15.Eng muammoli 5 ta yo‘nalishni aniqlang (eng yuqori kechikishlar asosida). 

flights.groupby(['ORIGIN_CITY', 'DEST_CITY'])['DEPARTURE_DELAY'].max().sort_values(ascending=False).head(5)
# Out:
# ORIGIN_CITY  DEST_CITY
# Birmingham   Dallas-Fort Worth    1988.0
# Richmond     Dallas-Fort Worth    1878.0
# San Diego    Dallas-Fort Worth    1670.0
# Albuquerque  Dallas-Fort Worth    1649.0
# Detroit      Chicago              1631.0
# Name: DEPARTURE_DELAY, dtype: float64

# %%
# 16.Har bir aviakompaniya uchun eng ko‘p ishlatiladigan jo‘nash shahrini aniqlang. 

most_used_dest = flights.groupby('AIRLINE_y')['DEST_CITY'].agg(lambda x: x.mode()[0]).reset_index()

most_used_dest.columns = ['AIRLINE', 'MOST_USED_DEST_CITY']
print(most_used_dest)
# Out:
#                          AIRLINE MOST_USED_DEST_CITY
# 0           Alaska Airlines Inc.             Seattle
# 1         American Airlines Inc.   Dallas-Fort Worth
# 2   American Eagle Airlines Inc.             Chicago
# 3    Atlantic Southeast Airlines             Houston
# 4           Delta Air Lines Inc.             Atlanta
# 5         Frontier Airlines Inc.              Denver
# 6         Hawaiian Airlines Inc.            Honolulu
# 7                JetBlue Airways            New York
# 8          Skywest Airlines Inc.      Salt Lake City
# 9         Southwest Airlines Co.             Chicago
# 10              Spirit Air Lines      Ft. Lauderdale
# 11               US Airways Inc.           Charlotte
# 12         United Air Lines Inc.             Chicago
# 13                Virgin America       San Francisco

# %%
# 17.	Har bir oy uchun eng yomon ishlagan aviakompaniyani aniqlang.
